# %%
#print Statement Hope AI

# %%
print("Hope AI")
# Out:
# Hope AI

# %%
 # Buy input

# %%
#Enter your institute name? : HOPai AI

# %%
institute = input("Enter your institute name? : ")
print("Your institute name

# %%
#Addition

# %%
a= 43
b= 34
add = 77

# %%
add = a + b
print(add)

# %%
#Subtraction

# %%
a= 43
b= 34
Sub = 9

# %%
Sub = a - b
print(Sub)

# %%
#Multiplication

# %%
a= 63
b= 97
Mul = 6111

# %%
mul = a * b
print(mul)

# %%
#Division

# %%
a= 76
b= 31
float_div = 2.4516129032258065

# %%
a = 76
b = 31
float_div = a / b
print(float_div)

# %%
#Modulo

# %%
a= 76
b= 31
Modulo = 14

# %%
a = 76
b = 31
mod = a % b
print(mod)

# %%
#Power

# %%
a= 4
b= 4
power = 256

# %%
a = 4
b = 4
power = a ** b
print(power)
